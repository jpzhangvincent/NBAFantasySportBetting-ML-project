# %%
import requests
import json
from urllib import urlencode

# %%
requests.__version__
# Out:
# '2.9.1'

# %%
import pandas as pd

# %%
with open('../Data/players.json') as data_file:
    playid_data = json.load(data_file)

# %%
playid_df = pd.DataFrame(playid_data)

# %%
playid_df.head()
# Out:
#   firstName lastName  playerId      teamId
# 0    Quincy      Acy    203112  1610612758
# 1    Jordan    Adams    203919  1610612763
# 2    Steven    Adams    203500  1610612760
# 3     Arron  Afflalo    201167  1610612752
# 4    Alexis   Ajinca    201582  1610612740

# %%
playid_df.shape
# Out:
# (468, 4)

# %% [markdown]
# There are only 468 players in the league

# %%
ids_ls = playid_df['playerId']

# %%
ids_ls[1:10]
# Out:
# 1     203919
# 2     203500
# 3     201167
# 4     201582
# 5     202332
# 6     200746
# 7    1626146
# 8     202730
# 9       2754
# Name: playerId, dtype: int64

# %% [markdown]
# # Player profile

# %%
class PlayerBio:
    def __init__(self, playerid, leagueid = '00'):
        self._url = "http://stats.nba.com/stats/commonplayerinfo?"
        self._api_param = (('PlayerID',playerid),('LeagueID',leagueid)) 
        u_a = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:43.0) Gecko/20100101 Firefox/43.0'}
        self._x = requests.get(self._url, params=self._api_param,headers={"USER-AGENT":u_a})
        self._x = self._x.json()
    def bio(self): # to collect only one player
        return pd.DataFrame(self._x['resultSets'][0]['rowSet'],columns=self._x['resultSets'][0]['headers'])

# %%
#test
tt = PlayerBio(str(playid_df['playerId'][0]))

# %%
tt.bio()
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     203112     Quincy       Acy         Quincy Acy              Acy, Quincy
#
#   DISPLAY_FI_LAST            BIRTHDATE  SCHOOL COUNTRY LAST_AFFILIATION  \
# 0          Q. Acy  1990-10-06T00:00:00  Baylor     USA       Baylor/USA
#
#          ...            TEAM_ID TEAM_NAME  TEAM_ABBREVIATION TEAM_CODE  \
# 0        ...         1610612758     Kings                SAC     kings
#
#     TEAM_CITY  PLAYERCODE  FROM_YEAR TO_YEAR DLEAGUE_FLAG GAMES_PLAYED_FLAG
# 0  Sacramento  quincy_acy       2012    2015            Y                 Y
#
# [1 rows x 26 columns]

# %%
def collectAllPlayerBios(ids_ls):
    leagueid = '00'
    url = "http://stats.nba.com/stats/commonplayerinfo?"
    u_a = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:43.0) Gecko/20100101 Firefox/43.0'} #header is necessary
    allplayerBios_df_ls = []
    
    for playerid in ids_ls:
        api_param = (('PlayerID',str(playerid)),('LeagueID',leagueid))
        response = requests.get(url, params=api_param,headers={"USER-AGENT":u_a})
        response_json = response.json()
        response_df = pd.DataFrame(response_json['resultSets'][0]['rowSet'],columns=response_json['resultSets'][0]['headers'])
        allplayerBios_df_ls.append(response_df)
        
    allplayerBios_df = pd.concat(allplayerBios_df_ls,axis=0)
    return(allplayerBios_df)

# %%
test_allplayerBios = collectAllPlayerBios(ids_ls[1:5])

# %%
test_allplayerBios
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     203919     Jordan     Adams       Jordan Adams            Adams, Jordan
# 0     203500     Steven     Adams       Steven Adams            Adams, Steven
# 0     201167      Arron   Afflalo      Arron Afflalo           Afflalo, Arron
# 0     201582     Alexis    Ajinca      Alexis Ajinca           Ajinca, Alexis
#
#   DISPLAY_FI_LAST            BIRTHDATE                 SCHOOL      COUNTRY  \
# 0        J. Adams  1994-07-08T00:00:00                   UCLA          USA
# 0        S. Adams  1993-07-20T00:00:00             Pittsburgh  New Zealand
# 0      A. Afflalo  1985-10-15T00:00:00                   UCLA          USA
# 0       A. Ajinca  1988-05-06T00:00:00  Saint Etienne, France       France
#
#          LAST_AFFILIATION        ...            TEAM_ID  TEAM_NAME  \
# 0                UCLA/USA        ...         1610612763  Grizzlies
# 0  Pittsburgh/New Zealand        ...         1610612760    Thunder
# 0                UCLA/USA        ...         1610612752     Knicks
# 0   Saint Etienne, France        ...         1610612740   Pelicans
#
#    TEAM_ABBREVIATION  TEAM_CODE      TEAM_CITY     PLAYERCODE  FROM_YEAR  \
# 0                MEM  grizzlies        Memphis   jordan_adams       2014
# 0                OKC    thunder  Oklahoma City   steven_adams       2013
# 0                NYK     knicks       New York  arron_afflalo       2007
# 0                NOP   pelicans    New Orleans  alexis_ajinca       2008
#
#   TO_YEAR DLEAGUE_FLAG GAMES_PLAYED_FLAG
# 0    2015            Y                 Y
# 0    2015            N                 Y
# 0    2015            N                 Y
# 0    2015            Y                 Y
#
# [4 rows x 26 columns]

# %%
allPlayerBios = collectAllPlayerBios(ids_ls)

# %%
allPlayerBios.head(20)
# Out:
#    PERSON_ID FIRST_NAME      LAST_NAME      DISPLAY_FIRST_LAST  \
# 0     203112     Quincy            Acy              Quincy Acy
# 0     203919     Jordan          Adams            Jordan Adams
# 0     203500     Steven          Adams            Steven Adams
# 0     201167      Arron        Afflalo           Arron Afflalo
# 0     201582     Alexis         Ajinca           Alexis Ajinca
# 0     202332       Cole        Aldrich            Cole Aldrich
# 0     200746   LaMarcus       Aldridge       LaMarcus Aldridge
# 0    1626146      Cliff      Alexander         Cliff Alexander
# 0     202730      Lavoy          Allen             Lavoy Allen
# 0       2754       Tony          Allen              Tony Allen
# 0     202329  Al-Farouq          Aminu         Al-Farouq Aminu
# 0     200811        Lou       Amundson            Lou Amundson
# 0       2365      Chris       Andersen          Chris Andersen
# 0     101187       Alan       Anderson           Alan Anderson
# 0     202341      James       Anderson          James Anderson
# 0    1626147     Justin       Anderson         Justin Anderson
# 0     203937       Kyle       Anderson           Kyle Anderson
# 0        ...         1610612752         Knicks                NYK     knicks
# 0        ...         1610612740       Pelicans                NOP   pelicans
# 0        ...         1610612746       Clippers                LAC   clippers
# 0        ...         1610612759          Spurs                SAS      spurs
# 0        ...         1610612757  Trail Blazers                POR    blazers
# 0        ...         1610612754         Pacers                IND     pacers
# 0        ...         1610612763      Grizzlies                MEM  grizzlies
# 0        ...         1610612757  Trail Blazers                POR    blazers
# 0        ...         1610612752         Knicks                NYK     knicks
# 0        ...         1610612763      Grizzlies                MEM  grizzlies
# 0        ...         1610612764        Wizards                WAS    wizards
# 0        ...         1610612758          Kings                SAC      kings
# 0        ...         1610612742      Mavericks                DAL  mavericks
# 0        ...         1610612759          Spurs                SAS      spurs
# 0        ...         1610612740       Pelicans                NOP   pelicans
# 0        ...         1610612749          Bucks                MIL      bucks
# 0        ...         1610612752         Knicks                NYK     knicks
#
#        TEAM_CITY              PLAYERCODE  FROM_YEAR TO_YEAR DLEAGUE_FLAG  \
# 0     Sacramento              quincy_acy       2012    2015            Y
# 0        Memphis            jordan_adams       2014    2015            Y
# 0  Oklahoma City            steven_adams       2013    2015            N
# 0       New York           arron_afflalo       2007    2015            N
# 0    New Orleans           alexis_ajinca       2008    2015            Y
# 0    Los Angeles            cole_aldrich       2010    2015            Y
# 0    San Antonio       lamarcus_aldridge       2006    2015            N
# 0       Portland         cliff_alexander       2015    2015            N
# 0        Indiana             lavoy_allen       2011    2015            N
# 0        Memphis              tony_allen       2004    2015            N
# 0       Portland         al-farouq_aminu       2010    2015            N
# 0       New York            lou_amundson       2006    2015            Y
# 0        Memphis          chris_andersen       2001    2015            N
# 0     Washington           alan_anderson       2005    2015            Y
# 0     Sacramento          james_anderson       2010    2015            Y
# 0         Dallas         justin_anderson       2015    2015            Y
# 0    San Antonio           kyle_anderson       2014    2015            Y
# 0    New Orleans         ryan_j_anderson       2008    2015            N
# 0      Milwaukee   giannis_antetokounmpo       2013    2015            N
# 0       New York  thanasis_antetokounmpo       2015    2015            Y
#
#   GAMES_PLAYED_FLAG
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
# 0                 Y
#
# [20 rows x 26 columns]

# %%
allPlayerBios.columns
# Out:
# Index([u'PERSON_ID', u'FIRST_NAME', u'LAST_NAME', u'DISPLAY_FIRST_LAST',
#        u'DISPLAY_LAST_COMMA_FIRST', u'DISPLAY_FI_LAST', u'BIRTHDATE',
#        u'SCHOOL', u'COUNTRY', u'LAST_AFFILIATION', u'HEIGHT', u'WEIGHT',
#        u'SEASON_EXP', u'JERSEY', u'POSITION', u'ROSTERSTATUS', u'TEAM_ID',
#        u'TEAM_NAME', u'TEAM_ABBREVIATION', u'TEAM_CODE', u'TEAM_CITY',
#        u'PLAYERCODE', u'FROM_YEAR', u'TO_YEAR', u'DLEAGUE_FLAG',
#        u'GAMES_PLAYED_FLAG'],
#       dtype='object')

# %%
import pickle

# %%
with open('../Data/allPlayerBios.pickle', 'wb') as handle:
  pickle.dump(allPlayerBios, handle)

# %% [markdown]
# # Player Game Log

# %%
class GameLog:
    def __init__(self, playerid, season='2015-16',seasontype='Regular Season', leagueid='00'):
        self._url = "http://stats.nba.com/stats/playergamelog?"
        u_a = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:43.0) Gecko/20100101 Firefox/43.0'}
        self._api_param = (('LeagueID', leagueid),('PlayerID',playerid),('Season',season),('SeasonType',seasontype))
        self._x = requests.get(self._url, params=self._api_param,headers={"USER-AGENT":u_a})
        #print(self._x.raise_for_status)
        self._x = self._x.json()
    def log(self):
        return pd.DataFrame(self._x['resultSets'][0]['rowSet'],columns=self._x['resultSets'][0]['headers'])

# %%
tt_log = GameLog('203076')

# %%
tt_log.log()
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22015     203076  0021500857  FEB 25, 2016  NOP vs. OKC  W   38   11
# 1      22015     203076  0021500841  FEB 23, 2016    NOP @ WAS  L   37    3
# 2      22015     203076  0021500823  FEB 21, 2016    NOP @ DET  W   43   24
# 3      22015     203076  0021500811  FEB 19, 2016  NOP vs. PHI  W   38    9
# 4      22015     203076  0021500802  FEB 11, 2016    NOP @ OKC  L   31    8
# 5      22015     203076  0021500798  FEB 10, 2016  NOP vs. UTA  W   34    7
# 6      22015     203076  0021500782  FEB 08, 2016    NOP @ MIN  W   31   12
# 7      22015     203076  0021500763  FEB 06, 2016    NOP @ CLE  L   40   11
# 8      22015     203076  0021500747  FEB 04, 2016  NOP vs. LAL  L   39   16
# 9      22015     203076  0021500742  FEB 03, 2016    NOP @ SAS  L   37   11
# 10     22015     203076  0021500724  FEB 01, 2016  NOP vs. MEM  L   37   10
# 11     22015     203076  0021500710  JAN 30, 2016  NOP vs. BKN  W   40    9
# 12     22015     203076  0021500671  JAN 25, 2016  NOP vs. HOU  L   19    4
# 13     22015     203076  0021500657  JAN 23, 2016  NOP vs. MIL  W   36    8
# 14     22015     203076  0021500641  JAN 21, 2016  NOP vs. DET  W   36   13
# 15     22015     203076  0021500626  JAN 19, 2016  NOP vs. MIN  W   37   13
# 16     22015     203076  0021500618  JAN 18, 2016    NOP @ MEM  L   37    6
# 17     22015     203076  0021500598  JAN 15, 2016  NOP vs. CHA  W   35    8
# 18     22015     203076  0021500585  JAN 13, 2016    NOP @ SAC  W   37    8
# 19     22015     203076  0021500544  JAN 08, 2016  NOP vs. IND  L    3    1
# 20     22015     203076  0021500531  JAN 06, 2016  NOP vs. DAL  L   42   11
# 21     22015     203076  0021500501  JAN 02, 2016    NOP @ DAL  W   43   13
# 22     22015     203076  0021500487  DEC 31, 2015  NOP vs. LAC  L   38    7
# 23     22015     203076  0021500460  DEC 28, 2015    NOP @ ORL  L   28    9
# 24     22015     203076  0021500445  DEC 26, 2015  NOP vs. HOU  W   38    8
# 25     22015     203076  0021500436  DEC 25, 2015    NOP @ MIA  L   50   13
# 26     22015     203076  0021500432  DEC 23, 2015  NOP vs. POR  W   36   12
# 27     22015     203076  0021500409  DEC 20, 2015    NOP @ DEN  W   20    9
# 28     22015     203076  0021500396  DEC 18, 2015    NOP @ PHX  L   42    5
# 29     22015     203076  0021500380  DEC 16, 2015    NOP @ UTA  W   38    7
# 30     22015     203076  0021500366  DEC 14, 2015    NOP @ POR  L   42   11
# 31     22015     203076  0021500348  DEC 12, 2015    NOP @ CHI  L   42    8
# 32     22015     203076  0021500339  DEC 11, 2015  NOP vs. WAS  W   39    8
# 33     22015     203076  0021500312  DEC 07, 2015  NOP vs. BOS  L   30    8
# 34     22015     203076  0021500288  DEC 04, 2015  NOP vs. CLE  W   46   13
# 35     22015     203076  0021500274  DEC 02, 2015    NOP @ HOU  L   35    9
# 36     22015     203076  0021500266  DEC 01, 2015  NOP vs. MEM  L   41    4
# 37     22015     203076  0021500243  NOV 28, 2015    NOP @ UTA  L   44   12
# 38     22015     203076  0021500238  NOV 27, 2015    NOP @ LAC  L   28    7
# 39     22015     203076  0021500225  NOV 25, 2015    NOP @ PHX  W   39   11
# 40     22015     203076  0021500198  NOV 22, 2015  NOP vs. PHX  W   39   11
# 41     22015     203076  0021500182  NOV 20, 2015  NOP vs. SAS  W   39    9
# 42     22015     203076  0021500163  NOV 17, 2015  NOP vs. DEN  L    6    0
# 43     22015     203076  0021500145  NOV 15, 2015    NOP @ NYK  L   40   14
# 44     22015     203076  0021500112  NOV 10, 2015  NOP vs. DAL  W   19    8
# 45     22015     203076  0021500088  NOV 07, 2015    NOP @ DAL  L   39   11
# 46     22015     203076  0021500081  NOV 06, 2015  NOP vs. ATL  L   41   14
# 47     22015     203076  0021500056  NOV 03, 2015  NOP vs. ORL  L   36    3
# 48     22015     203076  0021500035  OCT 31, 2015  NOP vs. GSW  L   37    8
# 49     22015     203076  0021500015  OCT 28, 2015    NOP @ POR  L   41   10
# 50     22015     203076  0021500003  OCT 27, 2015    NOP @ GSW  L   35    4
#
#     FGA  FG_PCT       ...         DREB  REB  AST  STL  BLK  TOV  PF  PTS  \
# 0    26   0.423       ...            5    6    2    1    4    2   2   30
# 1     9   0.333       ...           17   20    3    2    1    3   1    9
# 2    34   0.706       ...           14   20    4    0    1    2   1   59
# 3    22   0.409       ...            5    7    1    2    2    2   3   34
# 4    14   0.571       ...            3    3    2    2    0    1   3   23
# 5    15   0.467       ...            2    4    5    0    1    0   5   19
# 15           8                1
# 16          -4                1
# 17          -5                1
# 18           2                1
# 19          -1                1
# 20          -3                1
# 21           7                1
# 22         -10                1
# 23         -12                1
# 24           7                1
# 25         -11                1
# 26          21                1
# 27          11                1
# 28         -18                1
# 29           8                1
# 30          -7                1
# 31           8                1
# 32          13                1
# 33         -24                1
# 34           7                1
# 35         -11                1
# 36          -1                1
# 37           1                1
# 38         -26                1
# 39           7                1
# 40          16                1
# 41          15                1
# 42          -2                1
# 43          -9                1
# 44          17                1
# 45          -7                1
# 46          -1                1
# 47          -2                1
# 48         -19                1
# 49          -8                1
# 50         -16                1
#
# [51 rows x 27 columns]

# %%
def collectAllPlayerGameLogs(ids_ls):
    leagueid = '00'
    url = "http://stats.nba.com/stats/playergamelog?"
    u_a = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:43.0) Gecko/20100101 Firefox/43.0'} #header is necessary
    allplayerGameLogs_df_ls = []
    season='2015-16'
    seasontype='Regular Season'
    
    for playerid in ids_ls:
        api_param = (('LeagueID', leagueid),('PlayerID',playerid),('Season',season),('SeasonType',seasontype))
        response = requests.get(url, params=api_param,headers={"USER-AGENT":u_a})
        response_json = response.json()
        response_df = pd.DataFrame(response_json['resultSets'][0]['rowSet'],columns=response_json['resultSets'][0]['headers'])
        allplayerGameLogs_df_ls.append(response_df)
        
    allplayerGameLogs_df = pd.concat(allplayerGameLogs_df_ls,axis=0)
    return(allplayerGameLogs_df)

# %%
allplayerGameLogs = collectAllPlayerGameLogs(ids_ls)

# %%
allplayerGameLogs.shape
# Out:
# (18964, 27)

# %%
len(allplayerGameLogs['Player_ID'].unique())
# Out:
# 459

# %% [markdown]
# Double check the number of players. Still reasonable.

# %%
with open('../Data/allplayerGameLogs.pickle', 'wb') as handle:
  pickle.dump(allplayerGameLogs, handle)

# %%
allplayerGameLogs.columns
# Out:
# Index([u'SEASON_ID', u'Player_ID', u'Game_ID', u'GAME_DATE', u'MATCHUP', u'WL',
#        u'MIN', u'FGM', u'FGA', u'FG_PCT', u'FG3M', u'FG3A', u'FG3_PCT', u'FTM',
#        u'FTA', u'FT_PCT', u'OREB', u'DREB', u'REB', u'AST', u'STL', u'BLK',
#        u'TOV', u'PF', u'PTS', u'PLUS_MINUS', u'VIDEO_AVAILABLE'],
#       dtype='object')

# %%
allplayerGameLogs.dtypes
# Out:
# SEASON_ID           object
# Player_ID          float64
# Game_ID             object
# GAME_DATE           object
# MATCHUP             object
# WL                  object
# MIN                float64
# FGM                float64
# FGA                float64
# FG_PCT             float64
# FG3M               float64
# FG3A               float64
# FG3_PCT            float64
# FTM                float64
# FTA                float64
# FT_PCT             float64
# OREB               float64
# DREB               float64
# REB                float64
# AST                float64
# STL                float64
# BLK                float64
# TOV                float64
# PF                 float64
# PTS                float64
# PLUS_MINUS         float64
# VIDEO_AVAILABLE    float64
# dtype: object
